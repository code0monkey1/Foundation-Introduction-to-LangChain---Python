# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from dataclasses import dataclass

@dataclass
class ColourContext:
    favourite_colour: str = "blue"
    least_favourite_colour: str = "yellow"

# %%
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model

model = init_chat_model("llama-3.3-70b-versatile", model_provider="groq")
agent = create_agent(
    model=model,
    context_schema=ColourContext  
)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='1524b525-dec8-4b02-99e7-af600cb602d7'),
#               AIMessage(content="I don't have any information about your personal preferences, including your favourite colour. I'm a large language model, I don't have the ability to know your personal details or preferences unless you share them with me. Would you like to share your favourite colour with me?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 55, 'prompt_tokens': 41, 'total_tokens': 96, 'completion_time': 0.138910783, 'completion_tokens_details': None, 'prompt_time': 0.004473449, 'prompt_tokens_details': None, 'queue_time': 0.059343515, 'total_time': 0.143384232}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_68f543a7cc', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d4cf0-51c4-7783-9b67-701caab9b994-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 55, 'total_tokens': 96})]}

# %% [markdown]
# ## Accessing Context

# %%
from langchain.tools import tool, ToolRuntime

@tool
def get_favourite_colour(runtime: ToolRuntime) -> str:
    """Get the favourite colour of the user"""
    return runtime.context.favourite_colour

@tool
def get_least_favourite_colour(runtime: ToolRuntime) -> str:
    """Get the least favourite colour of the user"""
    return runtime.context.least_favourite_colour

# %%
agent = create_agent(
    model=model,
    tools=[get_favourite_colour, get_least_favourite_colour],
    context_schema=ColourContext
)

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)

pprint(response)
# Out:
# /Users/chiranjeev/Documents/lca-lc-foundations/.venv/lib/python3.13/site-packages/pydantic/main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   return self.__pydantic_serializer__.to_python(
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='5ac6a704-c492-4563-923c-8ba87f26dfff'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '81vmgxzta', 'function': {'arguments': '{}', 'name': 'get_favourite_colour'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 267, 'total_tokens': 277, 'completion_time': 0.043017909, 'completion_tokens_details': None, 'prompt_time': 0.112713928, 'prompt_tokens_details': None, 'queue_time': 0.113142381, 'total_time': 0.155731837}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_68f543a7cc', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d4cf0-c55f-7d40-b430-a8eaa6a8c545-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {}, 'id': '81vmgxzta', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 267, 'output_tokens': 10, 'total_tokens': 277}),
#               ToolMessage(content='blue', name='get_favourite_colour', id='5c6bc3cd-f199-4cb2-8c93-b455b99defd2', tool_call_id='81vmgxzta'),
#               AIMessage(content='Your favourite colour is blue.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 289, 'total_tokens': 296, 'completion_time': 0.019399989, 'completion_tokens_details': None, 'prompt_time': 0.030362568, 'prompt_tokens_details': None, 'queue_time': 0.184369582, 'total_time': 0.049762557}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_45180df409', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d4cf0-c792-7930-b1a8-1d2bde8f4adc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 289, 'output_tokens': 7, 'total_tokens': 296})]}

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext(favourite_colour="green")
)

pprint(response)
# Out:
# /Users/chiranjeev/Documents/lca-lc-foundations/.venv/lib/python3.13/site-packages/pydantic/main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   return self.__pydantic_serializer__.to_python(
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='aaac2121-642c-472b-bc8a-b356ca31ce73'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '146fqb929', 'function': {'arguments': '{}', 'name': 'get_favourite_colour'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 267, 'total_tokens': 277, 'completion_time': 0.03732793, 'completion_tokens_details': None, 'prompt_time': 0.013640127, 'prompt_tokens_details': None, 'queue_time': 0.173820961, 'total_time': 0.050968057}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_45180df409', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d4cf1-9966-7eb0-a82a-1f9a0b1fcfce-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {}, 'id': '146fqb929', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 267, 'output_tokens': 10, 'total_tokens': 277}),
#               ToolMessage(content='green', name='get_favourite_colour', id='946991f6-461d-458f-b7a8-568e704c3e5b', tool_call_id='146fqb929'),
#               AIMessage(content='Your favourite colour is green.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 289, 'total_tokens': 296, 'completion_time': 0.018971962, 'completion_tokens_details': None, 'prompt_time': 0.088216927, 'prompt_tokens_details': None, 'queue_time': 0.30235024, 'total_time': 0.107188889}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_43d97c5965', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d4cf1-9b90-7682-ad1a-ae6955c7f7a1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 289, 'output_tokens': 7, 'total_tokens': 296})]}
