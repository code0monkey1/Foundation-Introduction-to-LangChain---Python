# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent

from langchain.chat_models import init_chat_model

model = init_chat_model(model="llama-3.1-8b-instant", model_provider="groq" , temperature=0)

agent = create_agent(
    model=model
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='ccdaa2fd-e684-4ef8-a23d-2337e011b33f'),
#               AIMessage(content="Hello Seán, nice to meet you. Green is a great colour, it's often associated with nature and growth. Do you have a particular shade of green that you like the most, or is it more of a general preference?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 48, 'prompt_tokens': 47, 'total_tokens': 95, 'completion_time': 0.102719547, 'completion_tokens_details': None, 'prompt_time': 0.003012512, 'prompt_tokens_details': None, 'queue_time': 0.046281208, 'total_time': 0.105732059}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d3f2e-186b-70f2-ba2b-09aeac35c10c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 47, 'output_tokens': 48, 'total_tokens': 95})]}

# %%
question = HumanMessage(content="What is my Name, and What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What is my Name, and What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='1ba0dc76-014c-4601-931c-8f774666c4b0'),
#               AIMessage(content="I don't have any information about you, including your name or favourite colour. I'm a large language model, I don't have the ability to retain personal information or recall previous conversations. Each time you interact with me, it's a new conversation and I don't have any prior knowledge about you. If you'd like to share your name and favourite colour with me, I'd be happy to chat with you about it!", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 87, 'prompt_tokens': 47, 'total_tokens': 134, 'completion_time': 0.247555142, 'completion_tokens_details': None, 'prompt_time': 0.004452996, 'prompt_tokens_details': None, 'queue_time': 0.098489793, 'total_time': 0.252008138}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d3f2e-c024-76b2-ab71-bfef575ff25a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 47, 'output_tokens': 87, 'total_tokens': 134})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    model=model,
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
