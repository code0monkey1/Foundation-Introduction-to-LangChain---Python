# %% [markdown]
# ## Tool definition

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool

@tool
def square_root(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root")
def tool1(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root", description="Calculate the square root of a number")
def tool1(x: float) -> float:
    return x ** 0.5

# %%
tool1.invoke({"x": 467})
# Out:
# 21.61018278497431

# %% [markdown]
# ## Adding to agents

# %%
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model

model = init_chat_model(model="llama-3.3-70b-versatile", model_provider="groq" , temperature=0)
agent = create_agent(
    model=model,
    tools=[tool1],
    system_prompt="You are an arithmetic wizard. Use your tools to calculate the square root and square of any number."
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="What is the square root of 467?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# The square root of 467 is 21.61018278497431.

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='What is the square root of 467?', additional_kwargs={}, response_metadata={}, id='2bb0528e-e001-469d-9d9c-b251918aeffe'),
#  AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 't3bedktsv', 'function': {'arguments': '{"x":467}', 'name': 'square_root'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 243, 'total_tokens': 257, 'completion_time': 0.073226727, 'completion_tokens_details': None, 'prompt_time': 0.023622692, 'prompt_tokens_details': None, 'queue_time': 0.16262967, 'total_time': 0.096849419}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d3efd-3e37-7113-a00d-15140e9eaa56-0', tool_calls=[{'name': 'square_root', 'args': {'x': 467}, 'id': 't3bedktsv', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 243, 'output_tokens': 14, 'total_tokens': 257}),
#  ToolMessage(content='21.61018278497431', name='square_root', id='b9eac33e-3726-4c33-80c5-9250d195f2c3', tool_call_id='t3bedktsv'),
#  AIMessage(content='The square root of 467 is 21.61018278497431.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 274, 'total_tokens': 291, 'completion_time': 0.033942557, 'completion_tokens_details': None, 'prompt_time': 0.013870075, 'prompt_tokens_details': None, 'queue_time': 0.048776344, 'total_time': 0.047812632}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_68f543a7cc', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d3efd-3f81-7e30-9820-b7ae422b07d0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 274, 'output_tokens': 17, 'total_tokens': 291})]

# %%
print(response["messages"][1].tool_calls)
