# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="llama-3.3-70b-versatile", model_provider="groq" , temperature=0.01)

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='The Moon is a natural satellite and does not have a capital city. It is not a country or a political entity with its own government, so it does not have a capital. The Moon is simply a celestial body that orbits the Earth.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 49, 'prompt_tokens': 43, 'total_tokens': 92, 'completion_time': 0.157491759, 'completion_tokens_details': None, 'prompt_time': 0.012068323, 'prompt_tokens_details': None, 'queue_time': 0.161909454, 'total_time': 0.169560082}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_45180df409', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d3edc-b07c-7713-9430-ed0815b4427d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 49, 'total_tokens': 92})

# %%
print(response.content)
# Out:
# The Moon is a natural satellite and does not have a capital city. It is not a country or a political entity with its own government, so it does not have a capital. The Moon is simply a celestial body that orbits the Earth.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'logprobs': None,
#  'model_name': 'llama-3.3-70b-versatile',
#  'model_provider': 'groq',
#  'service_tier': 'on_demand',
#  'system_fingerprint': 'fp_45180df409',
#  'token_usage': {'completion_time': 0.157491759,
#                  'completion_tokens': 49,
#                  'completion_tokens_details': None,
#                  'prompt_time': 0.012068323,
#                  'prompt_tokens': 43,
#                  'prompt_tokens_details': None,
#                  'queue_time': 0.161909454,
#                  'total_time': 0.169560082,
#                  'total_tokens': 92}}

# %% [markdown]
# ## Customising your Model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="llama-3.3-70b-versatile", model_provider="groq" , temperature=2.0 ,max_tokens=500, max_retries=0)

response = model.invoke("What is the meaning of life? in Afrikaans and how does in compare to the meaning of life on the Moon?")
print(response.content)
# Out:
# I can help you with the first part of your question. The meaning of life in Afrikaans would translate to "die betekenis van die lewe."
#
# Regarding the comparison between the meaning of life on Earth (in Afrikaans or any other language) and the meaning of life on the Moon, I must explain that there is no known life on the Moon. The Moon has no atmosphere, extreme temperatures, and lacks liquid water, making it impossible for life as we know it to exist.
#
# ...

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="llama-3.3-70b-versatile", model_provider="groq" , temperature=2.0)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There is no capital of the Moon. The Moon is a natural satellite that orbits the Earth, and it does not have a government or a permanent human presence, so it does not have a capital city. While there have been several manned missions to the Moon in the past, there are no established settlements or cities on the Moon's surface.

# %%
model = init_chat_model(model="llama-3.3-70b-versatile", model_provider="groq" , temperature=2.0)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon is a natural satellite that orbits the Earth, and it doesn't have a capital city or any permanent human settlements. The Moon is largely uninhabited, except for a few robotic missions that have been sent there for exploration purposes.
#
# So, there is no capital city on the Moon! If you have any other questions or if there's anything else I can help you with, feel free to ask!

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model )

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='1f6d90de-38ed-4532-9a27-d87a6b2197d4'),
# ...

# %%
from langchain.messages import AIMessage,HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City"),
    HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='511f6cf8-fc0c-44c8-b942-09b69158b7b0'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='f6fc9802-63f9-44f9-96ee-a374f33338d6', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='32bcb5bc-eaac-42c2-808e-15476939815e'),
#               HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='6f43b07a-6256-48d7-b929-bab0663a6aaf'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='a8dc5f25-5ab9-4696-b13a-77c4d411f2f6', tool_calls=[], invalid_tool_calls=[]),
# ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City is a staple in science fiction, but it's not a reallocation of a capital city on the Moon. However, the idea of establishing a human settlement or city on the Moon has been explored in various science fiction stories, proposals, and conceptual designs.
#
# That being said, Luna City is the name given to a proposed lunar city in science fiction, particularly in the works of Robert A. Heinlein and other space-focused authors. If you were thinking of one such work I could expand further.
#
# However, to this date, humanity is yet to create any permanent, self-sustaining settlement on the Moon. Several space agencies, governments, and private companies have conducted lunar missions to study geology, test technology, and explore potential resources.
#
# Some real-world initiatives and plans for returning to and staying on the Moon for an extended time frame, such as NASA's lunar gateway program, do exist.
