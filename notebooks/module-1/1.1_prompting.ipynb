# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from langchain.chat_models import init_chat_model

system_prompt = "You are a science fiction writer, create a capital city at the users request."

model = init_chat_model(model="llama-3.3-70b-versatile", model_provider="groq" , temperature=2.0)

agent = create_agent(model=model, system_prompt=system_prompt)

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)


print(response['messages'][1].content)
# Out:
# I'm happy to create a capital city on the moon for you. Let's see...
#
# The capital city of the lunar nation, aptly named Lunaria, is called Selene. Located on the southeastern rim of the Mare Fecunditatis, a vast, dark basin that stretches over 900 kilometers in diameter, Selene is a marvel of modern lunar architecture and innovative engineering.
#
# Founded in the mid-21st century by a collective of visionary entrepreneurs and scientists, Selene has evolved into a vibrant hub of interplanetary commerce, research, and culture. The city's strategic location takes advantage of the moon's gravity and resources, leveraging in-situ materials and renewable energy sources to minimize reliance on Earth-based suppliers.
#
# **Selene's Unique Features:**
#
# 1. **Crystallarium Dome**: Selene's iconic centerpiece is a kilometers-wide, geodesic dome built from lightweight yet virtually indestructible lunar glass, crafted using moon regolith (soil). This majestic structure shelters the city's main districts from harm, offering breathtaking views of the celestial sky and protection from meteorites, extreme temperatures, and harmful radiation.
# 2. **Moonhoppers**: Efficient transportation systems and hyper-speed transit links seamlessly connect the different sectors of Selene, making quick work of the challenges posed by the low-gravity, airless lunar environment.
# 3. **New Horizon Boulevard**: A magnificent arterial thoroughfare traversing the city, this majestic road showcases vibrant commercial centers, public spaces, museums, research institutions, government complexes, and an astonishing glass-covered canal that mirrors the beauty of the surrounding space landscape.
# 4. **Helix**: The magnificent City-Spire of Selene – an awe-inspiring skyscraper housing a range of government agencies, research institutions, interplanetary businesses, and cultural institutions. It represents a masterpiece of space-age design.
# 5. **Low-Earth Lunar University (LELU)**: Based in the historic Old-Module Sector, this highly respected center of higher learning plays an influential role in driving the development of groundbreaking space technologies and promoting a collaborative understanding among international participants.
#
# **A city built among the cosmos, where terrestrial boundaries dissolve and visionary dreams unfold.** This is Selene – thriving lunar haven of knowledge and adventure.
#
# Feel free to inquire further about any specific features or sectors of the city you're interested in.

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token

# scifi_agent = create_agent(
#     model=model,
#     system_prompt=system_prompt
# )

# response = scifi_agent.invoke(
#     {"messages": [question]}
# )

# print(response['messages'][1].content)
# Out:
# Luna City, the crowning jewel of human settlements on the Moon. Founded in the year 2055, Luna City has evolved into a marvel of modern technology, sustainability, and innovative design. As the capital of the Moon, it's a beacon of progress and exploration, showcasing humanity's determination to push the boundaries of space habitation.
#
# **Geography and Climate**
#
# Luna City is situated in the southern region of the Moon, within the massive, elliptical impact crater known as Shackleton Crater. The city's location allows for optimal access to ice deposits, Helium-3, and other valuable lunar resources. The climate is, as expected, harsh and extreme, with temperatures ranging from -240°C to 127°C (surface temperatures can exceed those values during lunar days and drop drastically during the lunar nights). However, Luna City's ingenious architects and engineers have created an advanced environmental dome that protects its inhabitants from the unforgiving environment.
#
# **Architecture and Layout**
#
# Luna City's urban landscape is a remarkable example of human ingenuity. Built within a network of connected habitats and bio-domes, the city consists of several key modules:
#
# 1. **The Nexus**: The city's central hub, containing government institutions, commercial centers, and transportation hubs. A towering crystal-like spire made from an aluminum-titanium alloy serves as Luna City's unmistakable icon.
# 2. **The Sectors**: Six large, radiating habitats, each approximately five kilometers in diameter. These districts cater to various aspects of lunar civilization, such as: Residential (North, East, West), and Industry, Commerce, and Entertainment (NEC). Each Sector has its own distinct culture and architectural theme, inspired by cities on Earth (for example, the Residential sector features curved canals that mimic those in Venice).
# 3. **The Green Zones**: These parks and nature preserves help maintain the ecological balance within the city and contribute to air recycling and carbon filtration.
# 4. **The Helix Towers**: Twisted, curved skyscrapers containing laboratories, research institutions, medical facilities, and observatories for astronomical research.
# 5. **Aquaplanet Luna**: The Moon's biggest water feature, comprising vast artificial hydrothermal pools, fountains, and aquariological displays.
#
# **Government and Economy**
#
# The governance of Luna City is divided between the Moon-based Lunar Union (the representative authority and legislative body) and the Earth Union of Governments (overseeing international diplomatic, scientific, and inter-agency collaborations).
#
# The city's primary industries include:
#
# 1. **Resource extraction and refinement**: Harnessing lunar water ice, precious minerals, and metals.
# 2. **Renewable energies**: Harnessing solar, nuclear power, and low-orbiting orbit-based energy generation to support Earth-based infrastructure.
# 3. **Research and Development**: Scientific endeavors focusing on materials, propulsion systems, artificial intelligence, medicine, astrophysics, and geology.
#
# **Society, Culture, and Leisure**
#
# Luna City's multi-continental society boasts vibrant cultural diversity. Lunar festivities such as **Harmony Day**, **Galactic Conventions**, and **Cosmic Nights** attract interstellar tourists from other celestial hubs and space-based societies.
#
# Entertainment options are plenty:
#
# 1. **Starglass Opera House**: An esteemed theater dedicated to music, performance art, and drama under low-gravity.
# 2. **Virtual Odyssey Experience Parks**: Cutting-edge virtual- and simulated-exploration theme parks.
# 3. **SkyGolf Lunar Resorts**: Extravagant recreation centers with low-gravity athletic venues and exotic entertainment.
#
# Despite facing challenges such as resource scarcity, social cohesion issues, and space-based psychological pressures, Luna City offers a truly extraordinary standard of living, pushing the envelopes of human innovation and collaboration in the unforgiving yet mesmerizing lunar environment.
#
# With every generation of lunarians expanding, contributing, and refining their vision, it's an ever-inspiring beacon – radiating inspiration to humanity for further adventures beyond Moon-bound confines.
#
# And so Luna City remains the crown gem, symbol of the lunar dream for human kind and its interstellar presence: unbound.

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 13
#       1 system_prompt = """
#       2
#       3 You are a science fiction writer, create a space capital city at the users request.
#    (...)     10
#      11 """
# ---> 13 scifi_agent = create_agent(
#      14     model="gpt-5-nano",
#      15     system_prompt=system_prompt
#      16 )
#      18 response = scifi_agent.invoke(
#      19     {"messages": [question]}
#      20 )
#      22 print(response['messages'][1].content)
#
# NameError: name 'create_agent' is not defined

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]

# %%
response["structured_response"].name

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
