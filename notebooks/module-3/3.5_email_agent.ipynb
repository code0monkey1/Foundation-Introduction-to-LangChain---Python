# %% [markdown]
# email agent
# - authenticates user
#     - only then are they allowed into the "inbox"
#     - dynamic tools and prompt on the condition of there being an email and password in state that match hardcoded
# - checks "inbox"
#     - email in tool
# - sends emails
#     - human in the loop

# %%
import warnings
warnings.filterwarnings("ignore", message=".*Pydantic serializer warnings.*", category=UserWarning)

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from dataclasses import dataclass

@dataclass
class EmailContext:
    email_address: str = "julie@example.com"
    password: str = "password123"

# %%
from langchain.agents import AgentState

class AuthenticatedState(AgentState):
    authenticated: bool

# %%
from langchain.tools import tool, ToolRuntime
from langgraph.types import Command
from langchain.messages import ToolMessage

@tool
def check_inbox() -> str:
    """Check the inbox for recent emails"""
    return """
    Hi Julie, 
    I'm going to be in town next week and was wondering if we could grab a coffee?
    - best, Jane (jane@example.com)
    """

@tool
def send_email(to: str, subject: str, body: str) -> str:
    """Send an response email"""
    return f"Email sent to {to} with subject {subject} and body {body}"

@tool
def authenticate(email: str, password: str, runtime: ToolRuntime) -> Command:
    """Authenticate the user with the given email and password"""
    if email == runtime.context.email_address and password == runtime.context.password:
        return Command(update={
            "authenticated": True, 
            "messages": [ToolMessage(
                "Successfully authenticated", 
                tool_call_id=runtime.tool_call_id)]
        })
    else:
        return Command(update={
            "authenticated": False,
            "messages": [ToolMessage(
                "Authentication failed", 
                tool_call_id=runtime.tool_call_id)]
        })

# %%
from langchain.agents.middleware import wrap_model_call, ModelRequest, ModelResponse
from typing import Callable

@wrap_model_call
def dynamic_tool_call(request: ModelRequest, 
handler: Callable[[ModelRequest], ModelResponse]) -> ModelResponse:

    """Allow read inbox and send email tools only if user provides correct email and password"""

    authenticated = request.state.get("authenticated")
    
    if authenticated:
        tools = [check_inbox, send_email]
    else:
        tools = [authenticate]

    request = request.override(tools=tools) 
    return handler(request)

# %% [markdown]
# >Note: the prompts were modified since filming to constrain the model to more reliably match the filmed sequence. You may still experience different responses from the model, which is expected. You may need to modify the human message to provide appropriate responses.

# %%
from langchain.agents.middleware import dynamic_prompt

authenticated_prompt = """You are a helpful assistant that can check the inbox and send emails. 
Your first step after authentication is to check the inbox."""
unauthenticated_prompt = "You are a helpful assistant that can authenticate users."

@dynamic_prompt
def dynamic_prompt(request: ModelRequest) -> str:
    """Generate system prompt based on authentication status"""
    authenticated = request.state.get("authenticated")

    if authenticated:
        return authenticated_prompt
    else:
        return unauthenticated_prompt

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver
from langchain.agents.middleware import HumanInTheLoopMiddleware
from langchain.chat_models import init_chat_model

large_model  = init_chat_model("llama-3.3-70b-versatile", model_provider="groq")
agent = create_agent(
    large_model,
    tools=[authenticate, check_inbox, send_email],
    checkpointer=InMemorySaver(),
    state_schema=AuthenticatedState,
    context_schema=EmailContext,
    middleware=[
        dynamic_tool_call, 
        dynamic_prompt,
        HumanInTheLoopMiddleware(
            interrupt_on={
                "authenticate": False,
                "check_inbox": False,
                "send_email": True,
            })
        ]
    )

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [HumanMessage(content="julie@example.com, password123")]},
    context=EmailContext(),
    config=config
)

print(response['messages'][-1].content)

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="any draft is fine. don't check back.")]},
    context=EmailContext(),
    config=config
)

print(response['messages'][-1].content)

# %%
print(response['__interrupt__'][0].value['action_requests'][0]['args']['body'])
# Out:
# sure thing

# %%
from langgraph.types import Command

response = agent.invoke(
    Command( 
        resume={"decisions": [{"type": "approve"}]}  # or "reject"
    ), 
    config=config # Same thread ID to resume the paused conversation
)

print(response["messages"][-1].content)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'__interrupt__': [Interrupt(value={'action_requests': [{'args': {'body': 'Hi '
#                                                                           'Jane, '
#                                                                           'that '
#                                                                           'sounds '
#                                                                           'great! '
#                                                                           'I’d '
#                                                                           'love '
#                                                                           'to '
#                                                                           'catch '
#                                                                           'up '
#                                                                           'over '
#                                                                           'coffee. '
#                                                                           'Let '
#                                                                           'me '
#                                                                           'know '
#                                                                           'when '
#                                                                           'you '
#                                                                           'are '
#                                                                           'free.',
#                                                                   'subject': 'Re: '
#                                                                              'Coffee '
#                                                                              'Meeting',
#                                                                   'to': 'jane@example.com'},
#                                                          'description': 'Tool '
#                                                                         'execution '
#                                                                         'requires '
#                                                                         'approval\n'
#                                                                         '\n'
#                                                                         'Tool: '
#                                                                         'send_email\n'
#                                                                         'Args: '
#                                                                         "{'body': "
#                                                                         "'Hi "
#                                                                         'Jane, '
#                                                                         'that '
#                                                                         'sounds '
#                                                                         'great! '
#                                                                         'I’d '
#                                                                         'love '
#                                                                         'to '
#                                                                         'catch '
#                                                                         'up '
#                                                                         'over '
#                                                                         'coffee. '
#                                                                         'Let '
#                                                                         'me '
#                                                                         'know '
#                                                                         'when '
#                                                                         'you '
#                                                                         'are '
#                                                                         "free.', "
#                                                                         "'subject': "
#                                                                         "'Re: "
#                                                                         'Coffee '
#                                                                         "Meeting', "
#                                                                         "'to': "
#                                                                         "'jane@example.com'}",
#                                                          'name': 'send_email'}],
#                                     'review_configs': [{'action_name': 'send_email',
#                                                         'allowed_decisions': ['approve',
#                                                                               'edit',
#                                                                               'reject']}]},
#                              id='5f758f724375738b2dfa6f343747c695')],
#  'authenticated': True,
#  'messages': [HumanMessage(content='julie@example.com, password123', additional_kwargs={}, response_metadata={}, id='4b78af08-5990-4510-ab53-b724982eaf6b'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'snmrx2y05', 'function': {'arguments': '{"email":"julie@example.com","password":"password123"}', 'name': 'authenticate'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 242, 'total_tokens': 267, 'completion_time': 0.046273098, 'completion_tokens_details': None, 'prompt_time': 0.015418848, 'prompt_tokens_details': None, 'queue_time': 0.282942652, 'total_time': 0.061691946}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_e65acd3773', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d523d-828a-7c02-ba72-9788ca09ab74-0', tool_calls=[{'name': 'authenticate', 'args': {'email': 'julie@example.com', 'password': 'password123'}, 'id': 'snmrx2y05', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 242, 'output_tokens': 25, 'total_tokens': 267}),
#               ToolMessage(content='Successfully authenticated', name='authenticate', id='89641e1c-43f3-4aa8-ba46-08bb70c19344', tool_call_id='snmrx2y05'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'vb4xzzn3c', 'function': {'arguments': '{}', 'name': 'check_inbox'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 339, 'total_tokens': 350, 'completion_time': 0.017894568, 'completion_tokens_details': None, 'prompt_time': 0.112462981, 'prompt_tokens_details': None, 'queue_time': 0.175384399, 'total_time': 0.130357549}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_45180df409', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d523d-8489-7cd1-aeea-7984ef59d3ed-0', tool_calls=[{'name': 'check_inbox', 'args': {}, 'id': 'vb4xzzn3c', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 339, 'output_tokens': 11, 'total_tokens': 350}),
#               ToolMessage(content="\n    Hi Julie, \n    I'm going to be in town next week and was wondering if we could grab a coffee?\n    - best, Jane (jane@example.com)\n    ", name='check_inbox', id='60cdc414-06b8-41f8-ae49-bf6f18a25c79', tool_call_id='vb4xzzn3c'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'fkntrtk41', 'function': {'arguments': '{"body":"Hi Jane, that sounds great! I’d love to catch up over coffee. Let me know when you are free.","subject":"Re: Coffee Meeting","to":"jane@example.com"}', 'name': 'send_email'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 58, 'prompt_tokens': 397, 'total_tokens': 455, 'completion_time': 0.127116875, 'completion_tokens_details': None, 'prompt_time': 0.019340614, 'prompt_tokens_details': None, 'queue_time': 0.056970456, 'total_time': 0.146457489}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d523d-85ff-7dd1-bf40-006d4425efad-0', tool_calls=[{'name': 'send_email', 'args': {'body': 'Hi Jane, that sounds great! I’d love to catch up over coffee. Let me know when you are free.', 'subject': 'Re: Coffee Meeting', 'to': 'jane@example.com'}, 'id': 'fkntrtk41', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 397, 'output_tokens': 58, 'total_tokens': 455}),
#               HumanMessage(content="any draft is fine. don't check back.", additional_kwargs={}, response_metadata={}, id='8705cc9b-3b98-4d0d-a738-cb618fe5d5dc'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'b273ejg3q', 'function': {'arguments': '{"body":"sure thing","subject":"Re: draft","to":"julie@example.com"}', 'name': 'send_email'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 34, 'prompt_tokens': 471, 'total_tokens': 505, 'completion_time': 0.064284511, 'completion_tokens_details': None, 'prompt_time': 0.142240933, 'prompt_tokens_details': None, 'queue_time': 0.048886145, 'total_time': 0.206525444}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d523d-8700-7e22-9a48-6f65a3eed6a6-0', tool_calls=[{'name': 'send_email', 'args': {'body': 'sure thing', 'subject': 'Re: draft', 'to': 'julie@example.com'}, 'id': 'b273ejg3q', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 471, 'output_tokens': 34, 'total_tokens': 505}),
#               ToolMessage(content='Email sent to julie@example.com with subject Re: draft and body sure thing', name='send_email', id='94ae2104-29f4-4b66-b37a-ceb4f0cfc707', tool_call_id='b273ejg3q'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'th7kwqtyh', 'function': {'arguments': '{}', 'name': 'check_inbox'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 531, 'total_tokens': 542, 'completion_time': 0.017992128, 'completion_tokens_details': None, 'prompt_time': 0.04068143, 'prompt_tokens_details': None, 'queue_time': 0.33471683, 'total_time': 0.058673558}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_43d97c5965', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d523d-8842-7250-b56e-f1ad43202d18-0', tool_calls=[{'name': 'check_inbox', 'args': {}, 'id': 'th7kwqtyh', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 531, 'output_tokens': 11, 'total_tokens': 542}),
#               ToolMessage(content="\n    Hi Julie, \n    I'm going to be in town next week and was wondering if we could grab a coffee?\n    - best, Jane (jane@example.com)\n    ", name='check_inbox', id='9c90e856-dc54-44ff-85cd-bf1c0d92176c', tool_call_id='th7kwqtyh'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '7pgn162j5', 'function': {'arguments': '{"body":"Hi Jane, that sounds great! I’d love to catch up over coffee. Let me know when you are free.","subject":"Re: Coffee Meeting","to":"jane@example.com"}', 'name': 'send_email'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 55, 'prompt_tokens': 589, 'total_tokens': 644, 'completion_time': 0.083657196, 'completion_tokens_details': None, 'prompt_time': 0.093601415, 'prompt_tokens_details': None, 'queue_time': 0.070295295, 'total_time': 0.177258611}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d523d-8a38-7740-a918-1d44b35e5868-0', tool_calls=[{'name': 'send_email', 'args': {'body': 'Hi Jane, that sounds great! I’d love to catch up over coffee. Let me know when you are free.', 'subject': 'Re: Coffee Meeting', 'to': 'jane@example.com'}, 'id': '7pgn162j5', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 589, 'output_tokens': 55, 'total_tokens': 644})]}
